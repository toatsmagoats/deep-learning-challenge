# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN', 'NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_counts = application_df['APPLICATION_TYPE'].value_counts()
app_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_counts[app_counts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = application_df['CLASSIFICATION'].value_counts()
class_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_counts_greater_1 = class_counts.loc[class_counts > 1]
class_counts_greater_1
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_counts[class_counts < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
cat_numeric = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = cat_numeric.drop(['IS_SUCCESSFUL'], axis=1)
y = cat_numeric['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes_layer1, input_dim = number_input_features, activation = "tanh"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes_layer2, activation = "relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units = 1, activation = "relu"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5981 (23.36 KB)
# Trainable params: 5981 (23.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = "adam", metrics = ['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 2ms/step - loss: 2.5925 - accuracy: 0.6391
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0753 - accuracy: 0.6620
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.5977 - accuracy: 0.6819
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 1.3083 - accuracy: 0.6933
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.9481 - accuracy: 0.7194
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.8424 - accuracy: 0.7271
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 1.0630 - accuracy: 0.7124
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.9230 - accuracy: 0.7191
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.8846 - accuracy: 0.7236
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.9334 - accuracy: 0.7154
# Epoch 11/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.8456 - accuracy: 0.7166
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7764 - accuracy: 0.7182
# Epoch 13/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.8485 - accuracy: 0.7151
# Epoch 14/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.7657 - accuracy: 0.7152
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6974 - accuracy: 0.7207
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.7160 - accuracy: 0.7248
# Epoch 17/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.7328 - accuracy: 0.7198
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6598 - accuracy: 0.7174
# Epoch 19/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5840 - accuracy: 0.7197
# Epoch 20/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5713 - accuracy: 0.7290
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5610 - accuracy: 0.7317
# Epoch 22/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5717 - accuracy: 0.7242
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5587 - accuracy: 0.7308
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5661 - accuracy: 0.7250
# Epoch 25/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5613 - accuracy: 0.7300
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5598 - accuracy: 0.7294
# Epoch 27/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5631 - accuracy: 0.7290
# Epoch 28/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6067 - accuracy: 0.7284
# Epoch 29/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5815 - accuracy: 0.7264
# Epoch 30/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5629 - accuracy: 0.7311
# Epoch 31/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5589 - accuracy: 0.7304
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5568 - accuracy: 0.7312
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5650 - accuracy: 0.7294
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5592 - accuracy: 0.7301
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5605 - accuracy: 0.7288
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5590 - accuracy: 0.7342
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5655 - accuracy: 0.7212
# Epoch 38/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5599 - accuracy: 0.7318
# Epoch 39/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5590 - accuracy: 0.7319
# Epoch 40/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5588 - accuracy: 0.7285
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5553 - accuracy: 0.7341
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5540 - accuracy: 0.7341
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5577 - accuracy: 0.7325
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5615 - accuracy: 0.7333
# Epoch 45/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5582 - accuracy: 0.7312
# Epoch 46/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5600 - accuracy: 0.7271
# Epoch 47/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5631 - accuracy: 0.7350
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5542 - accuracy: 0.7346
# Epoch 49/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5531 - accuracy: 0.7350
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5532 - accuracy: 0.7339
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5534 - accuracy: 0.7351
# Epoch 52/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7352
# Epoch 53/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5567 - accuracy: 0.7317
# Epoch 54/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5531 - accuracy: 0.7343
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5651 - accuracy: 0.7331
# Epoch 56/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5763 - accuracy: 0.7330
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5730 - accuracy: 0.7338
# Epoch 58/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5688 - accuracy: 0.7358
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5720 - accuracy: 0.7300
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5640 - accuracy: 0.7345
# Epoch 61/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5631 - accuracy: 0.7359
# Epoch 62/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5637 - accuracy: 0.7348
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5759 - accuracy: 0.7314
# Epoch 64/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5605 - accuracy: 0.7347
# Epoch 65/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5626 - accuracy: 0.7366
# Epoch 66/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5619 - accuracy: 0.7349
# Epoch 67/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5650 - accuracy: 0.7365
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5672 - accuracy: 0.7319
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5657 - accuracy: 0.7287
# Epoch 70/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5544 - accuracy: 0.7341
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5553 - accuracy: 0.7354
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5590 - accuracy: 0.7352
# Epoch 73/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5507 - accuracy: 0.7365
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7369
# Epoch 75/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5524 - accuracy: 0.7362
# Epoch 76/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5567 - accuracy: 0.7375
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5543 - accuracy: 0.7353
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5625 - accuracy: 0.7352
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5847 - accuracy: 0.7306
# Epoch 80/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5766 - accuracy: 0.7340
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5764 - accuracy: 0.7357
# Epoch 82/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5759 - accuracy: 0.7360
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5760 - accuracy: 0.7362
# Epoch 84/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5770 - accuracy: 0.7359
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5813 - accuracy: 0.7315
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5858 - accuracy: 0.7330
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6018 - accuracy: 0.7323
# Epoch 88/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5870 - accuracy: 0.7290
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5832 - accuracy: 0.7284
# Epoch 90/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5772 - accuracy: 0.7312
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5732 - accuracy: 0.7362
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5748 - accuracy: 0.7371
# Epoch 93/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5866 - accuracy: 0.7252
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5766 - accuracy: 0.7369
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5766 - accuracy: 0.7362
# Epoch 96/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5783 - accuracy: 0.7331
# Epoch 97/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5722 - accuracy: 0.7360
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5705 - accuracy: 0.7359
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5701 - accuracy: 0.7369
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5767 - accuracy: 0.7365

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5920 - accuracy: 0.7243 - 494ms/epoch - 2ms/step
# Loss: 0.5919786095619202, Accuracy: 0.7243148684501648

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")

from google.colab import files

files.download("AlphabetSoupCharity.h5")
